# %% [markdown]
# # Interview
#
# This interview notebook uses Python 3.
#
# You may test your algorithms in this notebook by running the cell your code is in.
#
# If you have difficulties expressing your code in Python, pseudo code may be entered.
#
# ---
#
# ## Insert Your Name
#
# Insert your name into the variable `myName` and hit `Ctrl/Cmd + Enter` to run the code.

# %%
# Insert your name
myName = ""

print(myName)
